# %%
from PIL import Image
import numpy as np

# %%
n = 100
a = np.random.normal(size=(128))
b = np.random.normal(size=(128))
z = np.empty((n, 128))
for i, alpha in enumerate(np.linspace(start=0.0, stop=1.0, num=n)):
  z[i] = alpha * a + (1.0 - alpha) * b
